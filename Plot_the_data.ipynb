# %%
import pandas as pd

# %%
df = pd.read_csv("Test_prediction_precision.csv",header=None)

# %%
import matplotlib.pyplot as plt

plt.plot(df[0], df[1],'g-')
plt.ylabel('Prediction@k')
plt.xlabel('Training iteration')
plt.yticks([0.1, 0.3, 0.5, 0.7, 0.9])
plt.grid()
plt.show()
